# %% [markdown]
# relacao entre variaveis, tentar pca, reduzir features, ver oq é importante

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the HDF5 file
train_file_path = r"C:\Users\giuli\Documents\Open_Campus\Sleep_Apnea\00_DataProcessing\01_Data\01_Original\X_train.h5"

# %% [markdown]
# oversample? aumentar o numero de episodios de apneia no treino ou diminuir partes normais
# diminuir tamanho das janelas
# comecar com lr 0.01 ou 0.001
# classificar pela severidade se tiver x eventos suspeitos
# tentar uma regressao logistica
